# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os
import random
import cv2
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, Conv2DTranspose, concatenate, Input 
from tensorflow.keras.layers import Dropout, GlobalAveragePooling2D, Dense, Add, DepthwiseConv2D,Flatten
from tensorflow.keras.models import Model

# %%
def inception_module(x, filters_1x1, filters_3x3_reduce, filters_3x3, filters_5x5_reduce, filters_5x5, filters_pool_proj, name=None):
    conv_1x1 = Conv2D(filters_1x1, kernel_size=(1,1), padding='same', activation='relu')(x)
    
    preconv_3x3 = Conv2D(filters_3x3_reduce, kernel_size=(1,1), padding='same', activation='relu')(x)
    conv_3x3 = Conv2D(filters_3x3, kernel_size=(3,3), padding='same', activation='relu')(preconv_3x3)
    
    preconv_5x5 = Conv2D(filters_5x5_reduce, kernel_size=(1,1), padding='same', activation='relu')(x)
    conv_5x5 = Conv2D(filters_5x5, kernel_size=(5,5), padding='same', activation='relu')(preconv_5x5)
    
    pool_proj = MaxPooling2D((3,3), strides=(1,1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, kernel_size=(1,1), padding='same', activation='relu')(pool_proj)
    
    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3, name=name)
    
    return output

# %%
def residual_block(x, kernel_size, filters, s=2):
    f1,f2,f3 = filters
    x_shortcut = x
    
    # Shortcut Path
    x_shortcut = Conv2D(f3, kernel_size=(1,1), strides=(s,s), padding='valid')(x_shortcut)
    x_shortcut = BatchNormalization()(x_shortcut)
    
    # Main Path
    # First Component
    x = Conv2D(f1, kernel_size=(1,1), strides=(s,s), padding='valid')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # Second Component
    x = Conv2D(f2, kernel_size=kernel_size, strides=(1,1), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # Third Component
    x = Conv2D(f3, kernel_size=(1,1), strides=(1,1), padding='valid')(x)
    x = BatchNormalization()(x)
    
    x = Add()([x,x_shortcut])
    x = Activation('relu')(x)
    
    return x

# %%
def mobilenet_block(x, kernel_size, filters, strides):
    x = DepthwiseConv2D(kernel_size=(kernel_size,kernel_size), strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(filters, kernel_size=(1,1), strides=1, padding='valid')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %% [markdown]
# Q2

# %%
input_layer = Input(shape=(227,227,3))
x = Conv2D(32,kernel_size=(7,7), strides=1 , padding = 'same', activation = 'relu')(input_layer)
x = MaxPooling2D((3,3), strides=(2,2), padding = 'same')(x)
x = inception_module(x,64,96,128,16,32,32,name="inception_1")
x = inception_module(x,64,96,128,16,32,32,name="inception_2")
x = residual_block(x, (3,3), [64,64,128],  1)
x = residual_block(x, (3,3), [64,64,128],  1)
x = Flatten()(x)
x = Dense(1024, activation = 'relu')(x)
x = Dense(512, activation = 'relu')(x)
output = Dense(10, activation = 'softmax')(x)

model = Model(inputs=input_layer, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 227, 227, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 227, 227, 32  4736        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 114, 114, 32  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 114, 114, 96  3168        ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 114, 114, 16  528         ['max_pooling2d[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 114, 114, 32  0          ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 114, 114, 64  2112        ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 114, 114, 12  110720      ['conv2d_2[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 114, 114, 32  12832       ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 114, 114, 32  1056        ['max_pooling2d_1[0][0]']
#                                 )
#
#  inception_1 (Concatenate)      (None, 114, 114, 25  0           ['conv2d_1[0][0]',
#                                 6)                                'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 114, 114, 96  24672       ['inception_1[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 114, 114, 16  4112        ['inception_1[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 114, 114, 25  0          ['inception_1[0][0]']
#                                 6)
#
#  conv2d_7 (Conv2D)              (None, 114, 114, 64  16448       ['inception_1[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 114, 114, 12  110720      ['conv2d_8[0][0]']
#                                 8)
#
#  conv2d_11 (Conv2D)             (None, 114, 114, 32  12832       ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 114, 114, 32  8224        ['max_pooling2d_2[0][0]']
#                                 )
#
#  inception_2 (Concatenate)      (None, 114, 114, 25  0           ['conv2d_7[0][0]',
#                                 6)                                'conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 114, 114, 64  16448       ['inception_2[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 114, 114, 64  256        ['conv2d_14[0][0]']
#  rmalization)                   )
#
#  activation (Activation)        (None, 114, 114, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 114, 114, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 114, 114, 64  256        ['conv2d_15[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 114, 114, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 114, 114, 12  8320        ['activation_1[0][0]']
#                                 8)
#
#  conv2d_13 (Conv2D)             (None, 114, 114, 12  32896       ['inception_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 114, 114, 12  512        ['conv2d_16[0][0]']
#  rmalization)                   8)
#
#  batch_normalization (BatchNorm  (None, 114, 114, 12  512        ['conv2d_13[0][0]']
#  alization)                     8)
#
#  add (Add)                      (None, 114, 114, 12  0           ['batch_normalization_3[0][0]',
#                                 8)                                'batch_normalization[0][0]']
#
#  activation_2 (Activation)      (None, 114, 114, 12  0           ['add[0][0]']
#                                 8)
#
#  conv2d_18 (Conv2D)             (None, 114, 114, 64  8256        ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 114, 114, 64  256        ['conv2d_18[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 114, 114, 64  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 114, 114, 64  36928       ['activation_3[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 114, 114, 64  256        ['conv2d_19[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 114, 114, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 114, 114, 12  8320        ['activation_4[0][0]']
#                                 8)
#
#  conv2d_17 (Conv2D)             (None, 114, 114, 12  16512       ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_7 (BatchNo  (None, 114, 114, 12  512        ['conv2d_20[0][0]']
#  rmalization)                   8)
#
#  batch_normalization_4 (BatchNo  (None, 114, 114, 12  512        ['conv2d_17[0][0]']
#  rmalization)                   8)
#
#  add_1 (Add)                    (None, 114, 114, 12  0           ['batch_normalization_7[0][0]',
#                                 8)                                'batch_normalization_4[0][0]']
#
#  activation_5 (Activation)      (None, 114, 114, 12  0           ['add_1[0][0]']
#                                 8)
#
#  flatten (Flatten)              (None, 1663488)      0           ['activation_5[0][0]']
#
#  dense (Dense)                  (None, 1024)         1703412736  ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 512)          524800      ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 10)           5130        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 1,704,422,506
# Trainable params: 1,704,420,970
# Non-trainable params: 1,536
# __________________________________________________________________________________________________

# %%
input_layer=Input(shape=(227,227,3))
x = Conv2D(32, kernel_size=(3,3), strides = 2, padding = 'same')(input_layer)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = mobilenet_block(x, 3, 64, 1)
x = mobilenet_block(x, 3, 64, 1)

x = inception_module(x, 160,112,224,24,64,64, name='inception_1')
x = inception_module(x, 128,128,256,24,64,64, name='inception_2')

aux_avg = GlobalAveragePooling2D()(x)
aux_drop = Dropout(0.4)(aux_avg)
aux_output = Dense(10, activation = 'softmax')(aux_drop)

x = inception_module(x, 256, 160, 320, 32,128,128, name='inception_3')
x = inception_module(x, 384, 192, 384, 48,128,128, name='inception_4')

x = GlobalAveragePooling2D()(x)
x = Dropout(0.4)(x)
output = Dense(10, activation = 'softmax')(x)


model = Model(inputs = input_layer, outputs = [aux_output, output])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 227, 227, 3  0           []
#                                 )]
#
#  conv2d_21 (Conv2D)             (None, 114, 114, 32  896         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 114, 114, 32  128        ['conv2d_21[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 114, 114, 32  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 114, 114, 32  320        ['activation_6[0][0]']
#  v2D)                           )
#
#  batch_normalization_9 (BatchNo  (None, 114, 114, 32  128        ['depthwise_conv2d[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 114, 114, 32  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 114, 114, 64  2112        ['activation_7[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 114, 114, 64  256        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  activation_8 (Activation)      (None, 114, 114, 64  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 114, 114, 64  640        ['activation_8[0][0]']
#  onv2D)                         )
#
#  batch_normalization_11 (BatchN  (None, 114, 114, 64  256        ['depthwise_conv2d_1[0][0]']
#  ormalization)                  )
#
#  activation_9 (Activation)      (None, 114, 114, 64  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 114, 114, 64  4160        ['activation_9[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 114, 114, 64  256        ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  activation_10 (Activation)     (None, 114, 114, 64  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 114, 114, 11  7280        ['activation_10[0][0]']
#                                 2)
#
#  conv2d_27 (Conv2D)             (None, 114, 114, 24  1560        ['activation_10[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 114, 114, 64  0          ['activation_10[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 114, 114, 16  10400       ['activation_10[0][0]']
#                                 0)
#
#  conv2d_26 (Conv2D)             (None, 114, 114, 22  226016      ['conv2d_25[0][0]']
#                                 4)
#
#  conv2d_28 (Conv2D)             (None, 114, 114, 64  38464       ['conv2d_27[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 114, 114, 64  4160        ['max_pooling2d_3[0][0]']
#                                 )
#
#  inception_1 (Concatenate)      (None, 114, 114, 51  0           ['conv2d_24[0][0]',
#                                 2)                                'conv2d_26[0][0]',
#                                                                   'conv2d_28[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 114, 114, 12  65664       ['inception_1[0][0]']
#                                 8)
#
#  conv2d_33 (Conv2D)             (None, 114, 114, 24  12312       ['inception_1[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 114, 114, 51  0          ['inception_1[0][0]']
#                                 2)
#
#  conv2d_30 (Conv2D)             (None, 114, 114, 12  65664       ['inception_1[0][0]']
#                                 8)
#
#  conv2d_32 (Conv2D)             (None, 114, 114, 25  295168      ['conv2d_31[0][0]']
#                                 6)
#
#  conv2d_34 (Conv2D)             (None, 114, 114, 64  38464       ['conv2d_33[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 114, 114, 64  32832       ['max_pooling2d_4[0][0]']
#                                 )
#
#  inception_2 (Concatenate)      (None, 114, 114, 51  0           ['conv2d_30[0][0]',
#                                 2)                                'conv2d_32[0][0]',
#                                                                   'conv2d_34[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 114, 114, 16  82080       ['inception_2[0][0]']
#                                 0)
#
#  conv2d_39 (Conv2D)             (None, 114, 114, 32  16416       ['inception_2[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 114, 114, 51  0          ['inception_2[0][0]']
#                                 2)
#
#  conv2d_36 (Conv2D)             (None, 114, 114, 25  131328      ['inception_2[0][0]']
#                                 6)
#
#  conv2d_38 (Conv2D)             (None, 114, 114, 32  461120      ['conv2d_37[0][0]']
#                                 0)
#
#  conv2d_40 (Conv2D)             (None, 114, 114, 12  102528      ['conv2d_39[0][0]']
#                                 8)
#
#  conv2d_41 (Conv2D)             (None, 114, 114, 12  65664       ['max_pooling2d_5[0][0]']
#                                 8)
#
#  inception_3 (Concatenate)      (None, 114, 114, 83  0           ['conv2d_36[0][0]',
#                                 2)                                'conv2d_38[0][0]',
#                                                                   'conv2d_40[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 114, 114, 19  159936      ['inception_3[0][0]']
#                                 2)
#
#  conv2d_45 (Conv2D)             (None, 114, 114, 48  39984       ['inception_3[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 114, 114, 83  0          ['inception_3[0][0]']
#                                 2)
#
#  conv2d_42 (Conv2D)             (None, 114, 114, 38  319872      ['inception_3[0][0]']
#                                 4)
#
#  conv2d_44 (Conv2D)             (None, 114, 114, 38  663936      ['conv2d_43[0][0]']
#                                 4)
#
#  conv2d_46 (Conv2D)             (None, 114, 114, 12  153728      ['conv2d_45[0][0]']
#                                 8)
#
#  conv2d_47 (Conv2D)             (None, 114, 114, 12  106624      ['max_pooling2d_6[0][0]']
#                                 8)
#
#  inception_4 (Concatenate)      (None, 114, 114, 10  0           ['conv2d_42[0][0]',
#                                 24)                               'conv2d_44[0][0]',
#                                                                   'conv2d_46[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['inception_2[0][0]']
#  alAveragePooling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['inception_4[0][0]']
#  obalAveragePooling2D)
#
#  dropout (Dropout)              (None, 512)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 10)           5130        ['dropout[0][0]']
#
#  dense_4 (Dense)                (None, 10)           10250       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 3,125,732
# Trainable params: 3,125,220
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %% [markdown]
# Q1

# %%
input_layer=Input(shape=(224,224,3))
x = Conv2D(32,kernel_size=(11,11),strides=2, padding='same', activation='relu')(input_layer)
x = MaxPooling2D((3,3), strides=2, padding = 'same')(x)
x = inception_module(x, 64, 96, 128, 16, 32,32, name = 'inception_1')
x = inception_module(x, 364, 192,364, 48, 128, 128, name = 'inception_2')

x = GlobalAveragePooling2D()(x)
output= Dense(10, activation = 'Softmax')(x)

model =Model(inputs=input_layer,outputs=output)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_48 (Conv2D)             (None, 112, 112, 32  11648       ['input_3[0][0]']
#                                 )
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 56, 56, 32)  0           ['conv2d_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 56, 56, 96)   3168        ['max_pooling2d_7[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 56, 56, 16)   528         ['max_pooling2d_7[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 56, 56, 32)  0           ['max_pooling2d_7[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 56, 56, 64)   2112        ['max_pooling2d_7[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 56, 56, 128)  110720      ['conv2d_50[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 56, 56, 32)   12832       ['conv2d_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 56, 56, 32)   1056        ['max_pooling2d_8[0][0]']
#
#  inception_1 (Concatenate)      (None, 56, 56, 256)  0           ['conv2d_49[0][0]',
#                                                                   'conv2d_51[0][0]',
#                                                                   'conv2d_53[0][0]',
#                                                                   'conv2d_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 56, 56, 192)  49344       ['inception_1[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 56, 56, 48)   12336       ['inception_1[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 56, 56, 256)  0          ['inception_1[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 56, 56, 364)  93548       ['inception_1[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 56, 56, 364)  629356      ['conv2d_56[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 56, 56, 128)  153728      ['conv2d_58[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 56, 56, 128)  32896       ['max_pooling2d_9[0][0]']
#
#  inception_2 (Concatenate)      (None, 56, 56, 984)  0           ['conv2d_55[0][0]',
#                                                                   'conv2d_57[0][0]',
#                                                                   'conv2d_59[0][0]',
#                                                                   'conv2d_60[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 984)         0           ['inception_2[0][0]']
#  obalAveragePooling2D)
#
#  dense_5 (Dense)                (None, 10)           9850        ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 1,123,122
# Trainable params: 1,123,122
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Q3

# %%
input_layer=Input(shape=(227,227,3))

x = Conv2D(32, kernel_size=(7,7), strides = 1, padding = 'same', activation = 'relu')(input_layer)
x = MaxPooling2D((3,3), strides=2, padding='same')(x)

x = residual_block(x, (3,3), [64,64,128], 1)
x = residual_block(x, (3,3), [64,64,128], 1)

x = inception_module(x, 64,96,128,16,32,32, name='inception_1')
x = inception_module(x, 64,96,128,16,32,32, name='inception_2')

x = Flatten()(x)

x = Dense(512, activation='relu')(x)
x = Dense(1024, activation='relu')(x)

output = Dense(10, activation = 'Softmax')(x)

model =Model(inputs=input_layer,outputs=output)

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 227, 227, 3  0           []
#                                 )]
#
#  conv2d_61 (Conv2D)             (None, 227, 227, 32  4736        ['input_4[0][0]']
#                                 )
#
#  max_pooling2d_10 (MaxPooling2D  (None, 114, 114, 32  0          ['conv2d_61[0][0]']
#  )                              )
#
#  conv2d_63 (Conv2D)             (None, 114, 114, 64  2112        ['max_pooling2d_10[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 114, 114, 64  256        ['conv2d_63[0][0]']
#  ormalization)                  )
#
#  activation_11 (Activation)     (None, 114, 114, 64  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 114, 114, 64  36928       ['activation_11[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 114, 114, 64  256        ['conv2d_64[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 114, 114, 64  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  conv2d_65 (Conv2D)             (None, 114, 114, 12  8320        ['activation_12[0][0]']
#                                 8)
#
#  conv2d_62 (Conv2D)             (None, 114, 114, 12  4224        ['max_pooling2d_10[0][0]']
#                                 8)
#
#  batch_normalization_16 (BatchN  (None, 114, 114, 12  512        ['conv2d_65[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_13 (BatchN  (None, 114, 114, 12  512        ['conv2d_62[0][0]']
#  ormalization)                  8)
#
#  add_2 (Add)                    (None, 114, 114, 12  0           ['batch_normalization_16[0][0]',
#                                 8)                                'batch_normalization_13[0][0]']
#
#  activation_13 (Activation)     (None, 114, 114, 12  0           ['add_2[0][0]']
#                                 8)
#
#  conv2d_67 (Conv2D)             (None, 114, 114, 64  8256        ['activation_13[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 114, 114, 64  256        ['conv2d_67[0][0]']
#  ormalization)                  )
#
#  activation_14 (Activation)     (None, 114, 114, 64  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 114, 114, 64  36928       ['activation_14[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 114, 114, 64  256        ['conv2d_68[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 114, 114, 64  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  conv2d_69 (Conv2D)             (None, 114, 114, 12  8320        ['activation_15[0][0]']
#                                 8)
#
#  conv2d_66 (Conv2D)             (None, 114, 114, 12  16512       ['activation_13[0][0]']
#                                 8)
#
#  batch_normalization_20 (BatchN  (None, 114, 114, 12  512        ['conv2d_69[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_17 (BatchN  (None, 114, 114, 12  512        ['conv2d_66[0][0]']
#  ormalization)                  8)
#
#  add_3 (Add)                    (None, 114, 114, 12  0           ['batch_normalization_20[0][0]',
#                                 8)                                'batch_normalization_17[0][0]']
#
#  activation_16 (Activation)     (None, 114, 114, 12  0           ['add_3[0][0]']
#                                 8)
#
#  conv2d_71 (Conv2D)             (None, 114, 114, 96  12384       ['activation_16[0][0]']
#                                 )
#
#  conv2d_73 (Conv2D)             (None, 114, 114, 16  2064        ['activation_16[0][0]']
#                                 )
#
#  max_pooling2d_11 (MaxPooling2D  (None, 114, 114, 12  0          ['activation_16[0][0]']
#  )                              8)
#
#  conv2d_70 (Conv2D)             (None, 114, 114, 64  8256        ['activation_16[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 114, 114, 12  110720      ['conv2d_71[0][0]']
#                                 8)
#
#  conv2d_74 (Conv2D)             (None, 114, 114, 32  12832       ['conv2d_73[0][0]']
#                                 )
#
#  conv2d_75 (Conv2D)             (None, 114, 114, 32  4128        ['max_pooling2d_11[0][0]']
#                                 )
#
#  inception_1 (Concatenate)      (None, 114, 114, 25  0           ['conv2d_70[0][0]',
#                                 6)                                'conv2d_72[0][0]',
#                                                                   'conv2d_74[0][0]',
#                                                                   'conv2d_75[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 114, 114, 96  24672       ['inception_1[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 114, 114, 16  4112        ['inception_1[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 114, 114, 25  0          ['inception_1[0][0]']
#  )                              6)
#
#  conv2d_76 (Conv2D)             (None, 114, 114, 64  16448       ['inception_1[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 114, 114, 12  110720      ['conv2d_77[0][0]']
#                                 8)
#
#  conv2d_80 (Conv2D)             (None, 114, 114, 32  12832       ['conv2d_79[0][0]']
#                                 )
#
#  conv2d_81 (Conv2D)             (None, 114, 114, 32  8224        ['max_pooling2d_12[0][0]']
#                                 )
#
#  inception_2 (Concatenate)      (None, 114, 114, 25  0           ['conv2d_76[0][0]',
#                                 6)                                'conv2d_78[0][0]',
#                                                                   'conv2d_80[0][0]',
#                                                                   'conv2d_81[0][0]']
#
#  flatten_1 (Flatten)            (None, 3326976)      0           ['inception_2[0][0]']
#
#  dense_6 (Dense)                (None, 512)          1703412224  ['flatten_1[0][0]']
#
#  dense_7 (Dense)                (None, 1024)         525312      ['dense_6[0][0]']
#
#  dense_8 (Dense)                (None, 10)           10250       ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 1,704,404,586
# Trainable params: 1,704,403,050
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
